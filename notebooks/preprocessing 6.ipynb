# %%
import pandas as pd

# %%
df = pd.read_csv(r"../processed_data/main_data.csv")

# %%
df
# Out:
#           director_name         actor_1_name       actor_2_name  \
# 0         James Cameron          CCH Pounder   Joel David Moore
# 1        Gore Verbinski          Johnny Depp      Orlando Bloom
# 2            Sam Mendes      Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan            Tom Hardy     Christian Bale
# 4           Doug Walker          Doug Walker         Rob Walker
# ...                 ...                  ...                ...
# 6429     Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 6430     Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 6431          Joel Coen    Denzel Washington  Frances McDormand
# 6432     Erwin brothers         Zachary Levi        Anna Paquin
# 6433         Joe Wright       Peter Dinklage      Haley Bennett
#
#               actor_3_name                                genres  \
# 0                Wes Studi       Action Adventure Fantasy Sci-Fi
# ...

# %%
df = df.drop_duplicates(subset='movie_title')

# %%
df
# Out:
#           director_name         actor_1_name       actor_2_name  \
# 0         James Cameron          CCH Pounder   Joel David Moore
# 1        Gore Verbinski          Johnny Depp      Orlando Bloom
# 2            Sam Mendes      Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan            Tom Hardy     Christian Bale
# 4           Doug Walker          Doug Walker         Rob Walker
# ...                 ...                  ...                ...
# 6429     Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 6430     Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 6431          Joel Coen    Denzel Washington  Frances McDormand
# 6432     Erwin brothers         Zachary Levi        Anna Paquin
# 6433         Joe Wright       Peter Dinklage      Haley Bennett
#
#               actor_3_name                                genres  \
# 0                Wes Studi       Action Adventure Fantasy Sci-Fi
# ...

# %%
df.to_csv("../processed_data/main_data.csv")
